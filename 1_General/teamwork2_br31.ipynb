# %% [markdown]
# 일시 : 2020-07-07(화)
#
# 내용 : 파이썬을 이용해서 배스킨라빈스31 게임을 항상 이기는 기계 만들기(인공지능화)
#
# 팀원 : 최다인, 강민지, 천희국
#
# ---
#
# # 베스킨라빈스 31 인공지능화하기!
#
# 1. 30을 사용자가 무조건 부를수있게 하는 것
#
# 2. 2, 6, 10, 14, 18, 22, 26, 30 하나만 사용자가 부르기 시작해도 이어서 그 다음을 부를 수 있기에 무조건 승리
#
# https://blog.naver.com/jong1003min/220348353765
#
# 3. 위 숫자들은 +2 혹은 -2를 한 뒤에 4로 나누면 무조건 나머지가 0인 숫자들

# %%
# ===================== step1) 베스킨라빈스31 게임 진행=======================

import random

br31 = [i for i in range(1, 32)]

picked_num = random.randrange(0, 2)

x = [] # 컴퓨터
y = [] # 사람

# 숫자 부르기
while br31:

  if picked_num % 2 == 0:
    ans = random.randrange(1, 4)
    if len(br31) < ans:
      ans = len(br31)
    x += br31[:ans]
    print("컴퓨터: {}".format(x[-ans:]))
    del br31[:ans]

    if x[-1] == 31:
      print("사람이 이겼습니다.")
  
    
  else:
    ans = random.randrange(1, 4)
    if len(br31) < ans:
      ans = len(br31)
    y += br31[:ans]
    print("사람: {}".format(y[-ans:]))
    del br31[:ans]

    if y[-1] == 31:
      print("컴퓨터가 이겼습니다.")

  
  picked_num += 1
# Out:
# 컴퓨터: [1, 2]
# 사람: [3, 4]
# 컴퓨터: [5, 6]
# 사람: [7, 8]
# 컴퓨터: [9, 10, 11]
# 사람: [12, 13]
# 컴퓨터: [14, 15]
# 사람: [16, 17, 18]
# 컴퓨터: [19, 20]
# 사람: [21, 22]
# 컴퓨터: [23, 24]
# 사람: [25, 26, 27]
# 컴퓨터: [28, 29]
# 사람: [30, 31]
# 컴퓨터가 이겼습니다.

# %%
# =====================step2) 베스킨라빈스31 인공지능화=======================
# 못 함 
# clone coding 

from random import randrange



def computer_pick(br31, computer):
  computer_pick = randrange(1, 4)
  if len(br31) < computer_pick:
    computer_pick = len(br31)
  computer += br31[:computer_pick]
  print("컴퓨터가 부른 수: {}".format(computer[-computer_pick:]))
  del br31[:computer_pick]



def player_pick(br31, player):
  player_pick = randrange(1, 4)

  if len(br31) < player_pick:
    player_pick = len(br31)
  


  if br31[0] % 4 == 1 :
      player_pick = 2
  elif br31[0] % 4 == 2 :
      player_pick = 1
  elif br31[0] % 4 == 3 :
      pass
  else:
      player_pick = 3
      
  player += br31[:player_pick]

  print("플레이어가 부른 수 : {}".format(player[-player_pick:]))
  del br31[:player_pick] 


br31 = [i for i in range(1, 32)]
whos_first = randrange(0, 2) # 0: player, 1: computer
computer = []
player = []


if whos_first == 0:
  print('-----플레이어가 선을 잡았습니다-----')
else:
  print('-----컴퓨터가 선을 잡았습니다-----')

while True:

  if whos_first == 0:
    player_pick(br31, player)
    computer_pick(br31, computer)
    if len(br31) == 0:
      print("플레이어 승리!")
      print("-"*30)
      break
  
  else:
    computer_pick(br31, computer)
    if len(br31) == 0:
      print('플레이어 승리!')
      print("-"*30)
      break
    player_pick(br31, player)
# Out:
# -----컴퓨터가 선을 잡았습니다-----
# 컴퓨터가 부른 수: [1, 2]
# 플레이어가 부른 수 : [3, 4]
# 컴퓨터가 부른 수: [5]
# 플레이어가 부른 수 : [6]
# 컴퓨터가 부른 수: [7, 8]
# 플레이어가 부른 수 : [9, 10]
# 컴퓨터가 부른 수: [11, 12]
# 플레이어가 부른 수 : [13, 14]
# 컴퓨터가 부른 수: [15]
# 플레이어가 부른 수 : [16, 17, 18]
# 컴퓨터가 부른 수: [19]
# 플레이어가 부른 수 : [20, 21, 22]
# 컴퓨터가 부른 수: [23, 24, 25]
# 플레이어가 부른 수 : [26]
# 컴퓨터가 부른 수: [27]
# 플레이어가 부른 수 : [28, 29, 30]
# 컴퓨터가 부른 수: [31]
# 플레이어 승리!
# ------------------------------
